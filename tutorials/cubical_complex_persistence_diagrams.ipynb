# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

from shared_code import check_pershombox_availability

check_pershombox_availability()
from pershombox import cubical_complex_persistence_diagrams

# %% [markdown]
# `cubical_complex_persistence_diagrams` receives a `n` dimensional array which is interpreted as a filtrated cubical simpicial complex.

# %%
cubical_complex = np.array([[0, 2, 2],
                            [1, 3, 2],
                            [1, 1, 0]])

cubical_complex
# Out:
# array([[0, 2, 2],
#        [1, 3, 2],
#        [1, 1, 0]])

# %% [markdown]
# The values at the array positions reflect the filtration value. If we would evolve our cubical complex it would look like ...

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(6, 2))

for i, ax in enumerate(axs):
    cmp = cubical_complex <= i
    ax.matshow(cmp, cmap='Greys',  interpolation='nearest', vmin=0, vmax=1)
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
cubical_complex_persistence_diagrams(cubical_complex)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-304801f2a7c1> in <module>()
# ----> 1 cubical_complex_persistence_diagrams(cubical_complex)
#
# ~/Research/GAN/nips2017/tda-toolkit/pershombox/_software_backends/dipha_adapter.py in persistence_diagrams_of_filtrated_cubical_complex(filtrated_cubical_complex, limit_dimensions, dual, benchmark, set_inf_to_max_filt_val)
#     260                    limit_dimensions,
#     261                    dual,
# --> 262                    benchmark)
#     263
#     264         with open(persistence_diagram_file_path, "rb") as f:
#
# ~/Research/GAN/nips2017/tda-toolkit/pershombox/_software_backends/dipha_adapter.py in _run_dipha(input_file, output_file, limit_dimensions, dual, benchmark)
#      80     args += [input_file, output_file]
#      81
# ---> 82     p = subprocess.Popen([_get_dipha_path(),  *args], stdout=__stdout, stderr=__stderr)
#      83     p.wait()
#      84
#
# ~/anaconda3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     705                                 c2pread, c2pwrite,
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#     709             # Cleanup if the child failed starting.
#
# ~/anaconda3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1242                     else:
#    1243                         env_list = None  # Use execv instead of execve.
# -> 1244                     executable = os.fsencode(executable)
#    1245                     if os.path.dirname(executable):
#    1246                         executable_list = (executable,)
#
# ~/anaconda3/lib/python3.6/os.py in fsencode(filename)
#     796         'mbcs' (which is the default encoding).
#     797         """
# --> 798         filename = fspath(filename)  # Does type-checking of `filename`.
#     799         if isinstance(filename, str):
#     800             return filename.encode(encoding, errors)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %% [markdown]
# now let's calculate its persistent homology ...

# %%
dgms = cubical_complex_persistence_diagrams(cubical_complex)
dgms
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6b4b4bfe694e> in <module>()
# ----> 1 dgms = cubical_complex_persistence_diagrams(cubical_complex)
#       2 dgms
#
# ~/Research/GAN/nips2017/tda-toolkit/pershombox/_software_backends/dipha_adapter.py in persistence_diagrams_of_filtrated_cubical_complex(filtrated_cubical_complex, limit_dimensions, dual, benchmark, set_inf_to_max_filt_val)
#     260                    limit_dimensions,
#     261                    dual,
# --> 262                    benchmark)
#     263
#     264         with open(persistence_diagram_file_path, "rb") as f:
#
# ~/Research/GAN/nips2017/tda-toolkit/pershombox/_software_backends/dipha_adapter.py in _run_dipha(input_file, output_file, limit_dimensions, dual, benchmark)
#      80     args += [input_file, output_file]
#      81
# ---> 82     p = subprocess.Popen([_get_dipha_path(),  *args], stdout=__stdout, stderr=__stderr)
#      83     p.wait()
#      84
#
# ~/anaconda3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     705                                 c2pread, c2pwrite,
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#     709             # Cleanup if the child failed starting.
#
# ~/anaconda3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1242                     else:
#    1243                         env_list = None  # Use execv instead of execve.
# -> 1244                     executable = os.fsencode(executable)
#    1245                     if os.path.dirname(executable):
#    1246                         executable_list = (executable,)
#
# ~/anaconda3/lib/python3.6/os.py in fsencode(filename)
#     796         'mbcs' (which is the default encoding).
#     797         """
# --> 798         filename = fspath(filename)  # Does type-checking of `filename`.
#     799         if isinstance(filename, str):
#     800             return filename.encode(encoding, errors)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %% [markdown]
# Now we take a closer look on the barcodes in each dimension.

# %%
dgms[0]

# %% [markdown]
# * `(0.0, inf)` is the essential connected component which lives forever
# * `(0.0, 1)` reflects the merging of the two connected components as we rise the sublevelset-filtration from 0 to 1

# %%
dgms[1]

# %% [markdown]
# * `(2.0, 3.0)` represents the circle which occours when we reach filtration value `2` and dissapears when we reach `3`.
